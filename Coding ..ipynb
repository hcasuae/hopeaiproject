# %%
1.Write a Python program that prints numbers from 1 to 5.
Expected Output:
1 2 3 4 5

# %%
for num in range(1,6):
    print(num, end=' ')
# Out:
# 1 2 3 4 5

# %%
2.Write a Python program to print the first 5 even numbers. Expected Output:
2 4 6 8 10

# %%
def nums():
    for num in range(1,11):
        if (num%2==0):
            print(num, end=' ')

# %%
list=nums()
# Out:
# 2 4 6 8 10

# %%
3.Write a Python program to print the sum of numbers from 1 to 10. 
Expected Output:55

# %%
my_list = []
for num in range(11):
    my_list.append(num)
Total=sum(my_list)
print("Sum of numbers from 1-10: ",Total)
# Out:
# Sum of numbers from 1-10:  55

# %%
4.Write a Python function to find the factorial of 5. Expected Output:
120

# %%
import math
mylist = []
for num in range(5):
    mylist.append(num+1)
mylist.reverse()
total=math.prod(my_list)
print(total)
# Out:
# 120

# %%
5.Write a Python program to check if a number is prime. Expected Output (for input 7):
7 is a prime number

# %%
n=int(input("Enter"))
for i in range (n):
    if (n==1):
        print("Prime")
    elif (n%2==0):
        if (i==(n-1)):
            print("Not a Prime Number")
    elif (i==(n-1)):
        print(n,"is a prime number")
# Out:
# Enter 7
# 7 is a prime number
